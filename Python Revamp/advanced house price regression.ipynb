# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import io
# %matplotlib inline
# %cd D:\simplilear\python\data sets\Datasets\Advance House Price Regression
# Out:
# D:\simplilear\python\data sets\Datasets\Advance House Price Regression

# %%
train=pd.read_csv("train.csv")
test=pd.read_csv("test.csv")

# %%
train.shape
# Out:
# (1460, 81)

# %%
test.shape
# Out:
# (1459, 80)

# %%
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
test.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
train.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
test.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# Length: 80, dtype: object

# %%
test["SalePrice"]=80085

# %%
test.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
lists=train.isnull().sum().sort_values(ascending=False)

# %%
lists[lists>0]
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageCond        81
# GarageType        81
# GarageFinish      81
# GarageQual        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# dtype: int64

# %%
data=pd.concat([train,test],axis=0)

# %%
data.shape
# Out:
# (2919, 81)

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC          2909
# MiscFeature     2814
# Alley           2721
# Fence           2348
# FireplaceQu     1420
#                 ...
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# SalePrice          0
# Length: 81, dtype: int64

# %%
notavail=['PoolQC','Alley','MiscFeature','Fence','FireplaceQu']
for col in notavail:
    data[col]=data[col].fillna("NA")

# %%
data=data.dropna()

# %%
obj=data.select_dtypes(include="object")
num=data.select_dtypes(include=np.number)

# %%
garagecols=["GarageCond","GarageQual",'GarageFinish',"GarageType"]
for col in garagecols:
    obj[col]=obj[col].fillna("NoGarage")
# Out:
# <ipython-input-19-39709ae96ad2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obj[col]=obj[col].fillna("NoGarage")

# %%
from sklearn.preprocessing import LabelEncoder

# %%
 le=LabelEncoder()

# %%
obj=obj.apply(le.fit_transform)

# %%
obj
# Out:
#       MSZoning  Street  Alley  LotShape  LandContour  Utilities  LotConfig  \
# 0            3       1      1         3            3          0          4
# 1            3       1      1         3            3          0          2
# 2            3       1      1         0            3          0          4
# 3            3       1      1         0            3          0          0
# 4            3       1      1         0            3          0          2
# ...        ...     ...    ...       ...          ...        ...        ...
# 1451         3       1      1         3            3          0          4
# 1452         4       1      1         3            3          0          4
# 1455         4       1      1         3            3          0          4
# 1456         3       1      1         3            3          0          4
# 1458         3       1      1         3            3          0          4
#
# ...

# %%
comb=pd.concat([obj,num],axis=1)

# %%
comb
# Out:
#       MSZoning  Street  Alley  LotShape  LandContour  Utilities  LotConfig  \
# 0            3       1      1         3            3          0          4
# 1            3       1      1         3            3          0          2
# 2            3       1      1         0            3          0          4
# 3            3       1      1         0            3          0          0
# 4            3       1      1         0            3          0          2
# ...        ...     ...    ...       ...          ...        ...        ...
# 1451         3       1      1         3            3          0          4
# 1452         4       1      1         3            3          0          4
# 1455         4       1      1         3            3          0          4
# 1456         3       1      1         3            3          0          4
# 1458         3       1      1         3            3          0          4
#
# ...
